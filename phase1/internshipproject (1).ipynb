# %%
# !pip install groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 9.4 MB/s eta 0:00:00

# %%
from groq import Groq

# %%
from groq import Groq

client = Groq(
    api_key=userdata.get("GROQ_KEY")
)

# %%
response = client.chat.completions.create(
    model="llama-3.1-70b-versatile",
    messages=[
        {
            "role":"user",
            "content":"What is RAG?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /tmp/ipykernel_15034/2633371089.py in <cell line: 0>()
# ----> 1 response = client.chat.completions.create(
#       2     model="llama-3.1-70b-versatile",
#       3     messages=[
#       4         {
#       5             "role":"user",
#
# /usr/local/lib/python3.12/dist-packages/groq/resources/chat/completions.py in create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     459           timeout: Override the client-level default timeout for this request, in seconds
#     460         """
# --> 461         return self._post(
#     462             "/openai/v1/chat/completions",
#     463             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/groq/_base_client.py in post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1282             method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1283         )
# -> 1284         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1285
#    1286     def patch(
#
# /usr/local/lib/python3.12/dist-packages/groq/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1069
#    1070                 log.debug("Re-raising status error")
# -> 1071                 raise self._make_status_error_from_response(err.response) from None
#    1072
#    1073             break
#
# BadRequestError: Error code: 400 - {'error': {'message': 'The model `llama-3.1-70b-versatile` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}

# %%
from groq import Groq

client = Groq(api_key=userdata.get("GROQ_KEY"))

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# openai/gpt-oss-120b
# canopylabs/orpheus-arabic-saudi
# canopylabs/orpheus-v1-english
# groq/compound
# meta-llama/llama-4-scout-17b-16e-instruct
# whisper-large-v3
# llama-3.1-8b-instant
# groq/compound-mini
# openai/gpt-oss-safeguard-20b
# whisper-large-v3-turbo
# llama-3.3-70b-versatile
# meta-llama/llama-prompt-guard-2-22m
# openai/gpt-oss-20b
# allam-2-7b
# meta-llama/llama-prompt-guard-2-86m
# qwen/qwen3-32b

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "What is RAG?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# RAG can have multiple meanings depending on the context. Here are a few possible interpretations:
#
# 1. **RAG (Raise and Give)**: RAG is a common term used in the UK and other countries to refer to a charity fundraising campaign, often organized by students, where participants engage in activities such as sponsored walks, runs, or other events to raise money for a good cause.
# 2. **RAG (Radio Access Gateway)**: In telecommunications, RAG refers to a Radio Access Gateway, which is a network device that connects wireless base stations to a core network, enabling communication between mobile devices and the wider network.
# 3. **RAG (Red-Amber-Green)**: In project management and business, RAG is an acronym used to describe a simple color-coded status system, where:
# 	* Red indicates a problem or issue that needs attention.
# 	* Amber (or Yellow) indicates a warning or caution.
# 	* Green indicates everything is going well or is on track.
# 4. **Other meanings**: RAG can also refer to a rag (a piece of cloth), a rag doll, or a style of music (e.g., ragtime).
#
# Without more context, it's difficult to determine which definition is most relevant. If you have any additional information or clarification, I'd be happy to try and provide a more specific answer.

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "What is Retrieval-Augmented Generation (RAG) in Artificial Intelligence?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Retrieval-Augmented Generation (RAG) is a type of artificial intelligence (AI) technique used in natural language processing (NLP) and machine learning. It combines the strengths of two separate approaches:
#
# 1. **Retrieval-based models**: These models retrieve relevant information from a database or knowledge graph to answer a question or complete a task.
# 2. **Generative models**: These models generate new text or data based on a given input or prompt.
#
# In RAG, the retrieval-based model is used to fetch relevant information from a database, and then the generative model uses this information to generate a response. The key idea is to leverage the strengths of both approaches:
#
# * The retrieval-based model provides a solid foundation of factual information, ensuring that the generated response is accurate and informed.
# * The generative model allows for creative and flexible generation of text, taking into account the context and nuances of the input prompt.
#
# RAG has several benefits, including:
#
# * **Improved accuracy**: By combining retrieval and generation, RAG can produce more accurate and informative responses.
# * **Increased flexibility**: RAG can generate text in a variety of styles and formats, depending on the specific application.
# * **Reduced hallucination**: RAG is less prone to "hallucination" (i.e., generating false or fabricated information), as it is grounded in the factual information retrieved from the database.
#
# RAG has applications in various areas, such as:
#
# * Question answering
# * Text summarization
# * Conversational AI
# * Language translation
# * Content generation
#
# Overall, Retrieval-Augmented Generation is a powerful technique that combines the strengths of retrieval-based and generative models to produce more accurate, informative, and engaging text.

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key=userdata.get("GEMINI_KEY"))

# %%
# !pip install -q google-genai

# %%
from google import genai

client = genai.Client(
    api_key=userdata.get("GEMINI_KEY")
)

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is Retrieval-Augmented Generation?"
)

print(response.text)
# Out:
# **Retrieval-Augmented Generation (RAG)** is an AI framework that enhances the capabilities of Large Language Models (LLMs) by giving them access to external, up-to-date, and domain-specific information beyond their original training data.
#
# In simpler terms, it's like giving a very smart student (the LLM) access to a library and teaching them how to find and use specific, relevant books (retrieved documents) *before* answering a question, rather than just relying on what they vaguely remember from their general studies.
#
# ### Why is RAG Needed? (The Problem it Solves)
#
# While LLMs are incredibly powerful, they have some inherent limitations:
#
# 1.  **Knowledge Cutoff:** Their knowledge is limited to the data they were trained on, which has a specific cutoff date. They can't access real-time or very recent information.
# 2.  **Hallucinations:** If asked about something outside their training data or in a niche domain, LLMs might "hallucinate" – meaning they generate plausible-sounding but incorrect or fabricated information.
# 3.  **Lack of Specificity/Proprietary Data:** They don't have access to an organization's internal documents, proprietary databases, or highly specialized domain knowledge.
# 4.  **Source Attribution:** It's often hard to verify the claims made by an LLM or determine where it got its information.
# 5.  **Context Window Limitations:** While LLM context windows are growing, you can't feed *all* possible background information into every prompt.
#
# RAG addresses these issues by providing LLMs with **retrieved, factual context** at the time of generation.
#
# ### How Does RAG Work? (The Process)
#
# RAG typically involves two main phases:
#
# #### 1. Indexing / Preparation (Offline - done once or periodically)
#
# This phase prepares your external knowledge base for efficient retrieval:
#
# *   **Data Ingestion:** Collect all your relevant data sources (documents, web pages, databases, PDFs, etc.).
# *   **Chunking:** Break down large documents into smaller, manageable "chunks" or passages. This is crucial because it's easier and more efficient to search for relevant small pieces of information.
# *   **Embedding:** Convert each text chunk into a numerical representation called an "embedding" (a vector). These embeddings capture the semantic meaning of the text. Text chunks with similar meanings will have embeddings that are numerically close to each other.
# *   **Vector Database Storage:** Store these embeddings along with their corresponding original text chunks in a specialized database called a "vector database" or "vector store." This database is optimized for quick similarity searches.
#
# #### 2. Retrieval & Generation (Online - at query time)
#
# This phase happens every time a user asks a question:
#
# 1.  **User Query:** A user submits a question or prompt (e.g., "What are the benefits of the new HR policy?").
# 2.  **Query Embedding:** The user's query is also converted into an embedding using the *same embedding model* that was used for the chunks.
# 3.  **Similarity Search:** The query's embedding is used to perform a similarity search in the vector database. The system finds the top 'N' most semantically similar text chunks (the "retrieved documents") from the knowledge base.
# 4.  **Prompt Augmentation:** The original user query is combined with these retrieved, relevant text chunks. This forms a new, "augmented" prompt that provides the LLM with specific context.
#     *   **Example Augmented Prompt:** "Based on the following information: [Retrieved Chunk 1], [Retrieved Chunk 2], [Retrieved Chunk 3], please answer the question: What are the benefits of the new HR policy?"
# 5.  **LLM Generation:** This augmented prompt is then sent to the LLM. The LLM uses the provided context to generate a factual and coherent answer, significantly reducing the chances of hallucination and ensuring accuracy based on the given sources.
# 6.  **Source Citation (Optional but Recommended):** Often, the system will also provide the sources (e.g., document names, page numbers) from which the relevant chunks were retrieved, enhancing transparency and trustworthiness.
#
# ### Benefits of RAG
#
# *   **Improved Accuracy and Factual Grounding:** Reduces hallucinations by grounding LLM responses in verifiable data.
# *   **Timeliness and Freshness:** LLMs can access the most up-to-date information without needing to be continuously retrained.
# *   **Domain-Specificity:** Allows LLMs to answer questions about proprietary, internal, or highly specialized domain data.
# *   **Transparency and Trust:** Enables source attribution, allowing users to verify the information.
# *   **Cost-Effective:** Avoids the enormous computational cost and time of continuously retraining large LLMs.
# *   **Reduced Data Privacy Concerns:** LLMs don't *learn* the new data; they simply use it as context for a single query.
#
# ### Common Use Cases
#
# *   **Enterprise Search:** Answering questions about internal company documents (HR policies, product specifications, financial reports).
# *   **Customer Support Chatbots:** Providing accurate answers to customer queries based on product manuals, FAQs, and support articles.
# *   **Healthcare:** Summarizing medical research, answering patient questions based on health guidelines.
# *   **Legal Research:** Analyzing case law, summarizing legal documents.
# *   **Academic Research:** Finding specific information within large bodies of academic papers.
#
# In essence, RAG bridges the gap between the vast general knowledge of LLMs and the need for specific, accurate, and up-to-date information from diverse external sources.

# %% [markdown]
# Embeddings

# %%
sentences = [
    "Dogs are friendly animals.",
    "Cats love sleeping during the day.",
    "Artificial Intelligence is transforming technology.",
    "Machine Learning is a branch of AI.",
    "Deep Learning uses neural networks.",
    "Kerala is famous for its backwaters.",
    "The Earth revolves around the Sun.",
    "Python is a popular programming language.",
    "Football is played worldwide.",
    "Basketball is a fast-paced sport.",
    "Neural networks are inspired by the brain.",
    "Data science combines statistics and computing.",
    "The moon orbits the Earth.",
    "RAG improves LLM accuracy.",
    "Vector databases store embeddings.",
    "ChromaDB is a vector database.",
    "Groq provides fast AI inference.",
    "Gemini can generate embeddings.",
    "LangGraph helps build AI workflows.",
    "Retrieval is a key component of RAG."
]

# %%
from google import genai

client = genai.Client(
    api_key=userdata.get("GEMINI_KEY")
)

# %%
embeddings = []

for sentence in sentences:
    response = client.models.embed_content(
        model="text-embedding-004",
        contents=sentence
    )

    embeddings.append(response.embeddings[0].values)

print("Total embeddings:", len(embeddings))
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_15034/3726345298.py in <cell line: 0>()
#       2
#       3 for sentence in sentences:
# ----> 4     response = client.models.embed_content(
#       5         model="text-embedding-004",
#       6         contents=sentence
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in embed_content(self, model, contents, config)
#    5723     """
#    5724     if not self._api_client.vertexai:
# -> 5725       return self._embed_content(model=model, contents=contents, config=config)
#    5726
#    5727     if t.t_is_vertex_embed_content_model(model):
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _embed_content(self, model, contents, content, embedding_api_type, config)
#    4723     request_dict = _common.encode_unserializable_types(request_dict)
#    4724
# -> 4725     response = self._api_client.request(
#    4726         'post', path, request_dict, http_options
#    4727     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1400         http_method, path, request_dict, http_options
#    1401     )
# -> 1402     response = self._request(http_request, http_options, stream=False)
#    1403     response_body = (
#    1404         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1236         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237
# -> 1238     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1239
#    1240   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     468         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     369         result = None
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#     373
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     411                 retry_exc = self.retry_error_cls(fut)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#     415
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     182     def reraise(self) -> t.NoReturn:
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#     186
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#     475                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1213           timeout=http_request.timeout,
#    1214       )
# -> 1215       errors.APIError.raise_for_response(response)
#    1216       return HttpResponse(
#    1217           response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     132       response_json = response.body_segments[0].get('error', {})
#     133
# --> 134     cls.raise_error(response.status_code, response_json, response)
#     135
#     136   @classmethod
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     157     """
#     158     if 400 <= status_code < 500:
# --> 159       raise ClientError(status_code, response_json, response)
#     160     elif 500 <= status_code < 600:
#     161       raise ServerError(status_code, response_json, response)
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/text-embedding-004 is not found for API version v1beta, or is not supported for embedContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %%
from google import genai

client = genai.Client(api_key=userdata.get("GEMINI_KEY"))

for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview

# %%
# !pip install -q langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 5.4 MB/s eta 0:00:00

# %%
from google.colab import userdata
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings_model = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",
    google_api_key=userdata.get("GEMINI_KEY")
)

# %%
embedding = embeddings_model.embed_query(
    "Artificial Intelligence is transforming technology."
)

print(len(embedding))
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/embeddings.py in embed_query(self, text, task_type, title, output_dimensionality)
#     496         try:
# --> 497             result = self.client.models.embed_content(
#     498                 model=self.model,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in embed_content(self, model, contents, config)
#    5724     if not self._api_client.vertexai:
# -> 5725       return self._embed_content(model=model, contents=contents, config=config)
#    5726
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _embed_content(self, model, contents, content, embedding_api_type, config)
#    4724
# -> 4725     response = self._api_client.request(
#    4726         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1401     )
# -> 1402     response = self._request(http_request, http_options, stream=False)
#    1403     response_body = (
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1237
# -> 1238     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1239
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1214       )
# -> 1215       errors.APIError.raise_for_response(response)
#    1216       return HttpResponse(
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     133
# --> 134     cls.raise_error(response.status_code, response_json, response)
#     135
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     158     if 400 <= status_code < 500:
# --> 159       raise ClientError(status_code, response_json, response)
#     160     elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/embedding-001 is not found for API version v1beta, or is not supported for embedContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# /tmp/ipykernel_15034/1868045487.py in <cell line: 0>()
# ----> 1 embedding = embeddings_model.embed_query(
#       2     "Artificial Intelligence is transforming technology."
#       3 )
#       4
#       5 print(len(embedding))
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/embeddings.py in embed_query(self, text, task_type, title, output_dimensionality)
#     502         except ClientError as e:
#     503             msg = f"Error embedding content ({e.status}): {e}"
# --> 504             raise GoogleGenerativeAIError(msg) from e
#     505         except Exception as e:
#     506             msg = f"Error embedding content: {e}"
#
# GoogleGenerativeAIError: Error embedding content (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/embedding-001 is not found for API version v1beta, or is not supported for embedContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings_model = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001",
    google_api_key=userdata.get("GEMINI_KEY")
)

vector = embeddings_model.embed_query(
    "Artificial Intelligence is transforming technology."
)

print(len(vector))
# Out:
# 3072

# %%
sentences = [
    "Artificial Intelligence is transforming technology.",
    "Machine Learning is a branch of AI.",
    "Dogs are friendly animals."
]

embeddings = []

for sentence in sentences:
    response = client.models.embed_content(
        model="models/gemini-embedding-001",
        contents=sentence
    )

    embeddings.append(response.embeddings[0].values)

print("Embeddings created:", len(embeddings))
# Out:
# Embeddings created: 3

# %% [markdown]
# similarity search

# %%
# !pip install scikit-learn -q

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
sentences = [
    "Artificial Intelligence is transforming technology.",
    "Machine Learning is a branch of AI.",
    "Deep Learning uses neural networks.",
    "Dogs are friendly animals.",
    "Cats like sleeping.",
    "Kerala is famous for backwaters.",
    "Python is a programming language.",
    "Football is a popular sport.",
    "RAG improves answer accuracy.",
    "Vector databases store embeddings."
]

# %%
embeddings = []

for sentence in sentences:
    response = client.models.embed_content(
        model="models/gemini-embedding-001",
        contents=sentence
    )

    embeddings.append(response.embeddings[0].values)

print("Embeddings created:", len(embeddings))
# Out:
# Embeddings created: 10

# %%
query = "Tell me about Artificial Intelligence"

# %%
query_response = client.models.embed_content(
    model="models/gemini-embedding-001",
    contents=query
)

query_embedding = query_response.embeddings[0].values

# %%
similarities = cosine_similarity(
    [query_embedding],
    embeddings
)[0]

# %%
top_indices = np.argsort(similarities)[::-1][:5]

for i in top_indices:
    print()
    print("Sentence:", sentences[i])
    print("Similarity:", round(similarities[i], 4))
# Out:
# Sentence: Artificial Intelligence is transforming technology.
# Similarity: 0.7249
#
# Sentence: Machine Learning is a branch of AI.
# Similarity: 0.6706
#
# Sentence: Deep Learning uses neural networks.
# Similarity: 0.5826
#
# Sentence: Dogs are friendly animals.
# Similarity: 0.5749
#
# Sentence: Football is a popular sport.
# Similarity: 0.5552
